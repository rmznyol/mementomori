# %% [markdown]
# # Team Momento Mori
# In this project, we plan to analyze CDC Data to predict the likelihood of an individual dying from a natural cause or an unnatural cause.

# %% [markdown]
# ## 1) Installing Dependencies

# %%
# import the the essentials
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold, GridSearchCV, RepeatedStratifiedKFold, StratifiedKFold
#metrics
from sklearn.metrics import f1_score, recall_score, confusion_matrix, classification_report, roc_curve,  ConfusionMatrixDisplay

from sklearn.preprocessing import StandardScaler

#models
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import xgboost

import warnings
warnings.filterwarnings('ignore')

#user-defined modules
import data_preprocessing
import data_collection

# %% [markdown]
# ## 2) Loading the Data set

# %% [markdown]
# The data are obtained from the National Vital Statistics System of the United States Center for Disease Control. These data are from the Mortality Multiple Cause-of-Death for years ranging from 2005 to 2015.
# 1. Each csv file corresponds to a year of recorded deaths.
# 2. The raw data consist of 2,718,198 instances with 77 columns.  These columns are features which include codes for causes of death and as well as demographic information of the deceased, such as
#     - age of death
#     - sex of decedent
#     - education level of decedent
#     - marital status of decedent
#     - location of death relative to residence of decedent
#     - race
# 3. The features for cause(s) of death are coded here -- the correspondence can be found at https://www.cdc.gov/nchs/data/dvs/Multiple_Cause_Record_Layout_2015.pdf.

# %% [markdown]
# In our project, there are 10 different data sets corresponding to every year between 2005 and 2015.
#
# In order to collect data sets, please run the following and enter the sequence of the years that you wish to consider one by one. After, the final year that you would like to consider you can enter a blank input to end the sequence.
#
# For example: Suppose we want to install datasets from the years 2013 and 2015. After running the next code, we can type 2015 first and then press enter. Next, we will be asked again to enter a year, we can type 2013 and press enter again. Finally, we will be asked once more to enter a year input. We can leave the input space blank and enter press to finalize the sequence. In return, the data sets that belong to years 2013 and 2015 will be installed and collected as one single dataframe.
#
# **Please note** that, each of the data sets from 2005 to 2015 requires roughly about 1.6 GB memory. Which means that installing many years will require a large amoung of memory and calculations will be slower. For both training and computation purposes, it sufficies to install only one year.

# %%
df, causes = data_collection.DataCollection().dataframe
# Out:
# Please enter the sequence of years (between 2005 and 2015) e.g. 2015 . Enter blank to end the sequence or enter all to get all data sets:
# Please enter the sequence of years (between 2005 and 2015), enter blank to end the sequence or enter all to get all data sets:2014
# Current set of years : {'2014'}
# Please enter the sequence of years (between 2005 and 2015), enter blank to end the sequence or enter all to get all data sets:
# You entered blank, sequence is ended. The data from the following years will be loaded into memory:
# {'2014'}

# %%
df.head()
# Out:
#    resident_status  education_1989_revision  education_2003_revision  \
# 0                1                      NaN                      2.0
# 1                1                      NaN                      2.0
# 2                1                      NaN                      7.0
# 3                1                      NaN                      6.0
# 4                1                      NaN                      3.0
#
#    education_reporting_flag  month_of_death sex  detail_age_type  detail_age  \
# 0                         1               1   M                1          87
# 1                         1               1   M                1          58
# 2                         1               1   F                1          75
# 3                         1               1   M                1          74
# 4                         1               1   M                1          64
#
#    age_substitution_flag  age_recode_52  ...  record_condition_18  \
# 0                    NaN             43  ...                  NaN
# 1                    NaN             37  ...                  NaN
# 2                    NaN             41  ...                  NaN
# 3                    NaN             40  ...                  NaN
# 4                    NaN             38  ...                  NaN
#
#    record_condition_19  record_condition_20  race bridged_race_flag  \
# 0                  NaN                  NaN     1               NaN
# 1                  NaN                  NaN     1               NaN
# 2                  NaN                  NaN     1               NaN
# 3                  NaN                  NaN     1               NaN
# 4                  NaN                  NaN     1               NaN
#
#    race_imputation_flag  race_recode_3 race_recode_5  hispanic_origin  \
# 0                   NaN              1             1              100
# 1                   NaN              1             1              100
# 2                   NaN              1             1              100
# 3                   NaN              1             1              100
# 4                   NaN              1             1              100
#
#   hispanic_originrace_recode
# 0                          6
# 1                          6
# 2                          6
# 3                          6
# 4                          6
#
# [5 rows x 77 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2631171 entries, 0 to 2631170
# Data columns (total 77 columns):
#  #   Column                                                  Dtype
# ---  ------                                                  -----
#  0   resident_status                                         int64
#  1   education_1989_revision                                 float64
#  2   education_2003_revision                                 float64
#  3   education_reporting_flag                                int64
#  4   month_of_death                                          int64
#  5   sex                                                     object
#  6   detail_age_type                                         int64
#  7   detail_age                                              int64
#  8   age_substitution_flag                                   float64
#  9   age_recode_52                                           int64
#  10  age_recode_27                                           int64
#  11  age_recode_12                                           int64
#  12  infant_age_recode_22                                    float64
#  13  place_of_death_and_decedents_status                     int64
#  14  marital_status                                          object
#  15  day_of_week_of_death                                    int64
#  16  current_data_year                                       int64
#  17  injury_at_work                                          object
#  18  manner_of_death                                         float64
#  19  method_of_disposition                                   object
#  20  autopsy                                                 object
#  21  activity_code                                           float64
#  22  place_of_injury_for_causes_w00_y34_except_y06_and_y07_  float64
#  23  icd_code_10th_revision                                  object
#  24  358_cause_recode                                        int64
#  25  113_cause_recode                                        int64
#  26  130_infant_cause_recode                                 float64
#  27  39_cause_recode                                         int64
#  28  number_of_entity_axis_conditions                        int64
#  29  entity_condition_1                                      object
#  30  entity_condition_2                                      object
#  31  entity_condition_3                                      object
#  32  entity_condition_4                                      object
#  33  entity_condition_5                                      object
#  34  entity_condition_6                                      object
#  35  entity_condition_7                                      object
#  36  entity_condition_8                                      object
#  37  entity_condition_9                                      object
#  38  entity_condition_10                                     object
#  39  entity_condition_11                                     object
#  40  entity_condition_12                                     object
#  41  entity_condition_13                                     object
#  42  entity_condition_14                                     object
#  43  entity_condition_15                                     object
#  44  entity_condition_16                                     float64
#  45  entity_condition_17                                     float64
#  46  entity_condition_18                                     float64
#  47  entity_condition_19                                     float64
#  48  entity_condition_20                                     float64
#  49  number_of_record_axis_conditions                        int64
#  50  record_condition_1                                      object
#  51  record_condition_2                                      object
#  52  record_condition_3                                      object
#  53  record_condition_4                                      object
#  54  record_condition_5                                      object
#  55  record_condition_6                                      object
#  56  record_condition_7                                      object
#  57  record_condition_8                                      object
#  58  record_condition_9                                      object
#  59  record_condition_10                                     object
#  60  record_condition_11                                     object
#  61  record_condition_12                                     object
#  62  record_condition_13                                     object
#  63  record_condition_14                                     object
#  64  record_condition_15                                     float64
#  65  record_condition_16                                     float64
#  66  record_condition_17                                     float64
#  67  record_condition_18                                     float64
#  68  record_condition_19                                     float64
#  69  record_condition_20                                     float64
#  70  race                                                    int64
#  71  bridged_race_flag                                       float64
#  72  race_imputation_flag                                    float64
#  73  race_recode_3                                           int64
#  74  race_recode_5                                           int64
#  75  hispanic_origin                                         int64
#  76  hispanic_originrace_recode                              int64
# dtypes: float64(21), int64(21), object(35)
# memory usage: 1.5+ GB

# %% [markdown]
# ### Natural/Unnatural encoding
#     For this project we look at '113_cause_recode' as target column.
#
# We now encode the deaths which we rule unnatural.  By an **unnatural death**, we mean a death which is caused by one of the following causes:
# 1. Accident:
#     1. Unintentional injuries
#     2. Transportation
#     3. Motor vehicle, land/water/air/space
#     4. Nontransport accidents
#     5. Falls
#     6. Accidental discharge of firearms
#     7. Accidental drowning
#     8. Accidental exposure to smoke, fire, flames
#     9. Accidental poisoning
# 2. Homicide:
#     1. Assault, not by the below causes
#     2. Assault with firearms
#     3. Assault with unspecified means
# 3. Suicide:
#     1. Suicide by means other than the causes below
#     2. Suicide by discharge of firearm
#     3. Suidice by unspecified means
# 4. Execution
# 5. Undetermined intent
#     1. U.I. except those listed below
#     2. Discharge of firearms, undetermined intent
#     3. Other
# 6. Operations of war
# 7. Complications from medical and surgical care
#
# These correspond to cause of death codes 112-135 in the feature `113_cause_recode`.

# %%
display(causes)
# Out:
# 112    Accidents (unintentional injuries) (V01-X59,Y8...
# 113                    Transport accidents (V01-V99,Y85)
# 114    Motor vehicle accidents (V02-V04,V09.0,V09.2,V...
# 115    Other land transport accidents (V01,V05-V06,V0...
# 116    Water, air and space, and other and unspecifie...
# 117                 Nontransport accidents (W00-X59,Y86)
# 118                                      Falls (W00-W19)
# 119           Accidental discharge of firearms (W32-W34)
# 120         Accidental drowning and submersion (W65-W74)
# 121    Accidental exposure to smoke, fire and flames ...
# 122    Accidental poisoning and exposure to noxious s...
# 123    Other and unspecified nontransport accidents a...
# 124    Intentional self-harm (suicide) (*U03,X60-X84,...
# 125    Intentional self-harm (suicide) by discharge o...
# 126    Intentional self-harm (suicide) by other and u...
# 127         Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# 128    Assault (homicide) by discharge of firearms (*...
# 129    Assault (homicide) by other and unspecified me...
# 130                       Legal intervention (Y35,Y89.0)
# 131    Events of undetermined intent (Y10-Y34,Y87.2,Y...
# 132    Discharge of firearms, undetermined intent (Y2...
# 133    Other and unspecified events of undetermined i...
# 134     Operations of war and their sequelae (Y36,Y89.1)
# 135    Complications of medical and surgical care (Y4...
# Name: 113_cause_recode_json, dtype: object

# %% [markdown]
# There are no missing data in the target column:

# %%
df['113_cause_recode'].isna().sum()
# Out:
# 0

# %%
# One hot encoding for classification '113_cause_recode'
df['unnatural']=1
df.loc[df['113_cause_recode']<112,'unnatural']=0

# %%
df['unnatural'].value_counts(normalize=True)
# Out:
# 0    0.922728
# 1    0.077272
# Name: unnatural, dtype: float64

# %%
fig, ax = plt.subplots(1,1,figsize = (4,4))

colors = sns.color_palette('pastel')[0:5]
labels = ["Natural", "Unnatural"]
explode = [ 0, .2]

#create pie chart
ax.pie(df['unnatural'].value_counts(), 
       labels = labels,
       colors = colors, 
       explode = explode, 
       autopct='%.0f%%')
ax.set_title('Death Cause ');
fig.tight_layout()

# %% [markdown]
# As it can be seen above, about 92% of the deaths are natural, so we have classification problem with an inbalanced dataset.
#
# Next we dive deeper into features and investigate features for our prediction model.

# %% [markdown]
# ## 3) Exploratory Data Analysis
# Below we conduct exploratory data analysis in order to select features on which to train our model.

# %%
#Use this for eda
df_eda = df[df['detail_age']!=999]

# %% [markdown]
# ### 3.1) `detail_age`
# The feature `detail_age` records the age of death of the decedent.  We construct two sets of plots:
# 1. Two enhanced boxplots to plot the feature `detail_age` one for natural and another for unnatural deaths.
# 2. Two histograms of `detail_age`, one for natural and another for unnatural deaths.

# %%
from matplotlib.patches import Patch
fig, ax = plt.subplots(1,1,figsize = (6,4))

sns.boxenplot(x="detail_age", y="unnatural", 
            data=df_eda, orient="h",
            palette={1:"orange", 0:"blue"}, ax=ax,
             )

color_patches = [
    Patch(facecolor="red", label="unnatural = 0"),
    Patch(facecolor="blue", label="natural = 1")]
    
ax.set_ylabel('')
ax.set_yticklabels(['natural','unnatural']);

# %% [markdown]
# Based on these two boxplots, we can make the following conclusions:
# 1. Natural deaths are skewed left yet still have outliers to the right.
# 2. Unnatural deaths are more symmetrically distributed, but still have some outliers to the right.
# 3. The median age of unnatural death is significantly smaller than the median age of natural death.
#
# We record some of the summary statistics of these two distributions below:

# %%
age_group = df_eda.groupby('unnatural')

def quantile(x,q):
    return np.quantile(x,q)
age_group_agg = age_group.agg({"detail_age":[("mean", lambda x: np.round(np.mean(x), 1)),
                             ("min",np.min), 
                             ("q_25",lambda x: quantile(x,0.25)),
                             ('median',np.median), 
                             ("q_75",lambda x: quantile(x,0.75)),
                             ('max',np.max), 
                             ("IQR", lambda x: quantile(x,0.75) - quantile(x, 0.25)),
                                            ('sd',lambda x: np.round(np.std(x), 1))]})['detail_age']
print('Summary of the feature detail_age, by unnatural:')
print('=========================================================')
print(age_group_agg)
# Out:
# Summary of the feature detail_age, by unnatural:
# =========================================================
#            mean  min  q_25  median  q_75  max   IQR    sd
# unnatural
# 0          75.0    1  66.0    78.0  87.0  118  21.0  16.3
# 1          51.6    1  33.0    51.0  69.0  111  36.0  23.1

# %%
fig, ax = plt.subplots(1,1,figsize = (6,4))

bins = sorted(df_eda['detail_age'].unique())

sns.histplot(data = df_eda,
            x = 'detail_age',
            hue = 'unnatural',
            stat='probability', 
            bins = bins);

ax.set_xlabel('decedent age $x$', fontsize = 14)
ax.set_ylabel('probability of decedent\ndying at age $x$', fontsize = 14)
legend = ax.get_legend()
handles = legend.legendHandles
legend.remove()
ax.legend(handles, ['natural','unnatural'], title='Type of death')

fig.tight_layout()

# %%
fig, ax = plt.subplots(1,2,figsize = (8,4))

bins = sorted(df_eda['detail_age'].unique())

sns.histplot(data = df_eda[df_eda['unnatural'] == 0],
            x = 'detail_age',
#             hue = 'unnatural',
            stat='probability', 
            bins = bins,
            ax = ax[0]);
ax[0].set_xlabel('decedent age $x$', fontsize = 14)
ax[0].set_ylabel('probability of decedent\ndying at age $x$', fontsize = 14)
ax[0].set_title('Age of natural death')

sns.histplot(data = df_eda[df_eda['unnatural'] == 1],
            x = 'detail_age',
             color = 'red',
            stat='probability', 
            bins = bins,
            ax = ax[1]);
ax[1].set_xlabel('decedent age $x$', fontsize = 14)
ax[1].set_ylabel('probability of decedent\ndying at age $x$', fontsize = 14)
ax[1].set_title('Age of unnatural death')
fig.tight_layout()

# %% [markdown]
# ### 3.2) `sex`
# We also plot histograms for age of both natural and unnatural deaths colored by the variable `sex`.  The left-hand plot is the plot of the age of death for natural deaths, and the right-hand plot is for unnatural deaths.

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4))

#first plot is of the age distribution of natural deaths
sns.histplot(data = df_eda[df_eda.unnatural == 0],
            x = 'detail_age',
            ax = ax[0],
            hue = 'sex',
             stat = 'probability',
             hue_order = ['F','M'],
            bins = int(df_eda.loc[df_eda.unnatural == 0,'detail_age'].max())
            )
            
ax[0].set_title('Age of natural deaths,\ncolored by sex of decedent')
# ax[0].set_xticks(range(0,115,10))

#second plot is of the age distribution of unnatural deaths
sns.histplot(data = df_eda[df_eda.unnatural == 1],
            x = 'detail_age',
            ax = ax[1],
            hue = 'sex',
             stat = 'probability',
             hue_order = ["F","M"],
            bins = int(df_eda.loc[df_eda.unnatural == 1,'detail_age'].max())
            )
ax[1].set_title('Age of unnatural deaths,\ncolored by sex of decedent')
# ax[1].set_xticks(range(0,115,10))
fig.tight_layout()

# %% [markdown]
# We may draw the following conclusions:
# 1. Up until roughly age 80, males have a higher frequency of natural death than females.
# 2. Up until roughly age 90, males have a higher frequency of unnatural death than females.

# %% [markdown]
# ### 3.3) `marital_status`
# Below we plot histograms of the categorical variable `marital_status`, one for natural and the other for unnatural deaths.

# %%
fig, ax = plt.subplots(1,1,figsize = (6,4))

sns.histplot(data = df_eda,
            x = 'marital_status',
            hue = 'unnatural',
             hue_order = [0,1],
            stat = 'probability',
             ax = ax,
            );
legend = ax.get_legend()
handles = legend.legendHandles
legend.remove()
ax.legend(handles, ['natural','unnatural'], title='Type of death')
fig.tight_layout()

# %% [markdown]
# Now we plot the histograms based on the following random variables: let $X$ be the random variable indicating natural death or unnatural death, $A$ be the random variable denoting the age of death, and $Y$ be the random variable indicating marital status.  This is to see, after conditioning for type of death we desire to see what effect, if any, marital status has on the age of death.  Formally, for $a > 0$, we consider
#
# 1. $\mathbb{P}(A = a | X = 1, Y = s)$ for $s\in \{Married, Single, Widowed, Divorced, Unknown\}$,
# 2. $\mathbb{P}(A = a | X = 0, Y = s)$ for $s\in \{Married, Single, Widowed, Divorced, Unknown\}$,
#
# where $X = 1$ if the death is unnatural and $X = 0$ if the death is natural.

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,6))

#first plot is of the age distribution of natural deaths
sns.histplot(data = df_eda[(df_eda.unnatural == 0)],
            x = 'detail_age',
            ax = ax[0],
            hue = 'marital_status',
             hue_order = ['W','M','S','D','U'],
             stat = 'probability',
            bins = int(df_eda.loc[df_eda.unnatural == 0,'detail_age'].max())
            )
ax[0].set_title('Age of natural deaths,\ncolored by matrial status of decedent')

#second plot is of the age distribution of unnatural deaths
sns.histplot(data = df_eda[(df_eda.unnatural == 1)],
            x = 'detail_age',
            ax = ax[1],
            hue = 'marital_status',
             hue_order = ['W','M','S','D','U'],
             stat = 'probability',
            bins = int(df_eda.loc[df_eda.unnatural == 1,'detail_age'].max()))
ax[1].set_title('Age of unnatural deaths,\ncolored by marital status of decedent')

fig.tight_layout()

# %% [markdown]
# We draw the following conclusions:
# 1. Marital status has a significant effect on age of unnatural death, particularly for single (S) decedents.
# 2. We see what is expected for the distribution of natural death, namely, that it is more likely that as one is older that one is married or widowed.

# %% [markdown]
# ### 3.4) `education`

# %%
df_eda = data_preprocessing.DataPreprocesor().education_convertor(df_eda)

# %%
fig, ax = plt.subplots(1,1,figsize = (6,4))

sns.histplot(data = df_eda,
            x = 'education',
            hue = 'unnatural',
            stat = 'probability',
            bins = np.arange(1,10)-0.5
            );
legend = ax.get_legend()
handles = legend.legendHandles
legend.remove()
ax.legend(handles, ['natural','unnatural'], title='Type of death')
fig.tight_layout()

# %%
del df_eda

# %% [markdown]
# ### EDA Conclusions
# Based on our EDA, we will use the following features in our model: `detail_age`, `sex`, `marital_status`, `education`

# %% [markdown]
# ## 4) Data Cleaning

# %% [markdown]
# We begin cleaning the data by splitting the features obtained from the above exploratory data analysis into categorical features, which will require one-hot encoding, and continuous features, which will require median imputation, removal of missing values in the case of `education` and scaling in the case of `detail_age`.

# %%
continuous_variables = ['education_2003_revision',
                     'detail_age']

categorical_variables = ['marital_status','sex']

features_of_interest = continuous_variables + categorical_variables

# %% [markdown]
# ### 4.1) Inspection of missing data points

# %%
# Count Nan's: 
for column in df[features_of_interest]:
    print(f'\t {column} has: { df[column].isna().sum() } many missing points and { len(df[column].unique()) } many different unique values \n')
# Out:
# 	 education_2003_revision has: 241607 many missing points and 10 many different unique values
#
# 	 detail_age has: 0 many missing points and 117 many different unique values
#
# 	 marital_status has: 0 many missing points and 5 many different unique values
#
# 	 sex has: 0 many missing points and 2 many different unique values

# %% [markdown]
# We built a simple process for coding missing education data from the data documentation.  The process is described below.
# 1. In the feature `education_2003_revision` some of the instances use a 1989 code, and these are the codes which are `nan` values.  Unstated education levels, which are truly missing, are encoded with a `99`.
# 2. An instance is missing a recorded value for `education_2003_revision` if its `education_2003_revision` has the value 9.
#
# To clean the education data, we create a new feature, named `education` which returns the 2003 education revision and updates the instances which use the 1989 revision.  Values of 9 in `education_2003_revision`, which are unreported, are replaced with `np.nan` in the feature `education`, as they are truly missing values.
# <!--
#
# In addition to missing values above, our research revealed that 'detail_age' = 999 and 'education_2003_revision'==9  translates to missing data.
#
# Also NaN values for education_2003_revision are using the 1989 revision format of the item, which means we can potentialy recover missing points here by using data from education_1998_revision column. -->

# %%
print('\t Number of ACTUAL missing datapoints in detail_age column:', (df['detail_age']==999).sum(), '\n\n',
    '\t Number of ACTUAL missing datapoints in education_2003_revision column: ', (df['education_2003_revision']==9).sum())
# Out:
# 	 Number of ACTUAL missing datapoints in detail_age column: 571
#
#  	 Number of ACTUAL missing datapoints in education_2003_revision column:  50006

# %% [markdown]
# ### 4.2) Data Preprocessing

# %% [markdown]
# 1. First fill the fake missing columns of `education_2003_revision` by using appropriate data from `education_1989_revision` and unite them to `education` column
# 2. Drop all the remaning actual missing points from `detail_age` and `education` columns
# 3. One hot encode all the categorical variables
# 4. Return processed NaN-free data set and new features

# %%
pre_processor = data_preprocessing.DataPreprocesor()

df, features = pre_processor.get_clean_data_and_features(df)
# Out:
# 	 Number of dropped datapoints for detail_age column: 571
#
#  	 Number of dropped datapoints for education column:  53133

# %%
df.head()
# Out:
#    detail_age  unnatural  education  marital_status_D  marital_status_M  \
# 0        87.0          0        2.0                 0                 1
# 1        58.0          0        2.0                 1                 0
# 2        75.0          0        7.0                 0                 0
# 3        74.0          0        6.0                 1                 0
# 4        64.0          0        3.0                 1                 0
#
#    marital_status_S  marital_status_U  sex_F
# 0                 0                 0      0
# 1                 0                 0      0
# 2                 0                 0      1
# 3                 0                 0      0
# 4                 0                 0      0

# %%
df.unnatural.value_counts(normalize = True)
# Out:
# 0    0.92301
# 1    0.07699
# Name: unnatural, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize = (4,4))

colors = sns.color_palette('pastel')[0:5]
labels = ["Natural", "Unnatural"]
explode = [ 0, .2]

#create pie chart
ax.set_title('Death Cause After Cleaning NaNs ')
ax.pie(df['unnatural'].value_counts(),
       labels = labels, 
       colors = colors, 
       explode = explode, 
       autopct='%.0f%%');

# %% [markdown]
# ## 5) Choice Of Metric

# %% [markdown]
# Our choice of performance metric depends on our targeted end-user: life insurance companies.  To reduce the frequency of sticker shock based on discrepancy between advertised premia and final quotes, it is best for the model to prefer to make false positive errors instead of false negative errors.  However, the model should be penalized for making a large number of false positive errors, which happen when the model classifies the majority of training instances as unnatural deaths.  Therefore, we measure model performance by the macro f1 score.  Our baseline model for comparison was a model which classified an instance as an unnatural death with probability equal to the training proportion of unnatural deaths.

# %% [markdown]
# ##  6) MODEL SELECTION

# %% [markdown]
# ### 6.1) General Selection with Kfold Cross Validation

# %% [markdown]
# Our base models are as follows:
# 1. Guess unnatural death with training unnatural death proportion, i.e. unnatural death is a Bernoulli random variable with parameter $p \approx 0.08$.
# 2. Guess all instances as the majority class, i.e. as natural deaths.
# 3. Use a default `LogisticRegression`.
#
# We compared the following models against our base models:
# 1. A `LogisticRegression` with scaled continuous inputs and penalizing observations based on their value of `unnatural`: this is by using the parameter `class_weights = 'balanced'`.
# 2. `LogisticRegression` with class weights and no scaling.
# 3. Base `RandomForestClassifier`
# 4. `RandomForestClassifier` with balanced class weights as in (1).
# 5. Base Naive Bayes Classifier assuming normal distribution of the features.
# 6. `XGBoost` with 10 weak learners each of maxiumu depth 8, with class weighting of 700.

# %%
df_train, df_test = train_test_split(df.copy(),
                                     shuffle=True,
                                     random_state=123,
                                     test_size=.1,
                                     stratify=df['unnatural'].values)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

Scaler = ColumnTransformer([("scaler", StandardScaler(), ['detail_age','education'])], remainder='passthrough')

# %%
baseline_models = {
    "Random_Guessing" : DummyClassifier(strategy="stratified") ,
    "Guess_Everything_Natural" : DummyClassifier(strategy="most_frequent"),
    "Logistic_Regression": LogisticRegression()
}

# %%
models = {
    "Logistic_Regression_w_Scaling+Weights" : make_pipeline(Scaler,LogisticRegression(class_weight = 'balanced', penalty="l2")),
    "Logistic_Regression_w_Weights" : LogisticRegression(class_weight = 'balanced'),
    "Random_Forest_Classifier" : RandomForestClassifier(n_estimators=100,max_depth=8),
    "Random_Forest_Classifier_w_Weights" : RandomForestClassifier(n_estimators=100,max_depth=8,class_weight = 'balanced'),
    "Gaussian_Bayes" : GaussianNB(),
    "XGboost" : xgboost.XGBClassifier(n_estimators = 10,
                                      max_depth = 8, 
                                      scale_pos_weight = 700,
                                      random_state = 123)
}

# %%
models.update(baseline_models)

# %%
## Make a KFold object
n_splits = 5
kfold = StratifiedKFold(n_splits= n_splits, 
                random_state=123,
                shuffle=True)

## This arrays will hold the f1-macro and recall score for each model and split
f1s = np.zeros((len(models), n_splits))
rcls=np.zeros((len(models), n_splits))

## sets a split counter
i = 0

## loop through the kfold here
for train_index, test_index in kfold.split(df_train,df_train.unnatural):
    
    ## cv training and holdout set
    df_tt,  df_ho = df_train.iloc[train_index], df_train.iloc[test_index]
    
    ## ROC curve dictionary to display 
    ROC_dict = {}
    
    ##train the models in the split
    for model_index, (model_name, model) in enumerate(models.items()):
        print(model_name, '\n', f'Split: {i}')
        model.fit(df_tt[features], df_tt['unnatural'].values)
        pred = model.predict(df_ho[features])
        pred_proba = model.predict_proba(df_ho[features])[:,1]
        
        f1s[model_index,i] = f1_score(df_ho['unnatural'].values, pred, average = 'macro')
        rcls[model_index, i] = recall_score(df_ho['unnatural'].values, pred)
        
        print(f'{model_name} {i}th validation \n', classification_report(df_ho['unnatural'].values, pred),'\n')
        print('Prediction Percentages : \n', pd.Series(pred).value_counts(normalize=True))
        print('--'*30)
        ROC_dict[model_name] = {}
        ROC_dict[model_name]['fprs'], ROC_dict[model_name]['tprs'], ROC_dict[model_name]['cutoffs'] = roc_curve(df_ho['unnatural'].values,pred_proba)
    
    ##Display the ROC curve
    plt.figure(figsize=(10,8))
    plt.title(f'ROC Curve for split {i}')
    for model_name in ROC_dict.keys():
        plt.plot(ROC_dict[model_name]['fprs'], ROC_dict[model_name]['tprs'], label = f'{model_name}')
    
    plt.plot([0,1],[0,1],'k--', label ='Random Guess Curve')
    plt.xlabel('False Positive Rate', fontsize =16)
    plt.ylabel('True Positive Rate', fontsize =16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.legend(fontsize=14)

    plt.show()

    i = i + 1
# Out:
# Logistic_Regression_w_Scaling+Weights
#  Split: 0
# Logistic_Regression_w_Scaling+Weights 0th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35724
#
#     accuracy                           0.77    464001
#    macro avg       0.59      0.74      0.59    464001
# weighted avg       0.91      0.77      0.82    464001
#
#
# Prediction Percentages :
#  0    0.7393
# 1    0.2607
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Weights
#  Split: 0
# Logistic_Regression_w_Weights 0th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35724
#
#     accuracy                           0.77    464001
#    macro avg       0.59      0.74      0.59    464001
# weighted avg       0.91      0.77      0.82    464001
#
#
# Prediction Percentages :
#  0    0.7393
# 1    0.2607
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier
#  Split: 0
# Random_Forest_Classifier 0th validation
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    428277
#            1       0.67      0.26      0.38     35724
#
#     accuracy                           0.93    464001
#    macro avg       0.81      0.63      0.67    464001
# weighted avg       0.92      0.93      0.92    464001
#
#
# Prediction Percentages :
#  0    0.969815
# 1    0.030185
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier_w_Weights
#  Split: 0
# Random_Forest_Classifier_w_Weights 0th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90    428277
#            1       0.26      0.65      0.38     35724
#
#     accuracy                           0.83    464001
#    macro avg       0.62      0.75      0.64    464001
# weighted avg       0.91      0.83      0.86    464001
#
#
# Prediction Percentages :
#  0    0.810537
# 1    0.189463
# dtype: float64
# ------------------------------------------------------------
# Gaussian_Bayes
#  Split: 0
# Gaussian_Bayes 0th validation
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94    428277
#            1       0.32      0.37      0.34     35724
#
#     accuracy                           0.89    464001
#    macro avg       0.63      0.65      0.64    464001
# weighted avg       0.90      0.89      0.89    464001
#
#
# Prediction Percentages :
#  0    0.909446
# 1    0.090554
# dtype: float64
# ------------------------------------------------------------
# XGboost
#  Split: 0
# XGboost 0th validation
#                precision    recall  f1-score   support
#
#            0       0.99      0.00      0.00    428277
#            1       0.08      1.00      0.14     35724
#
#     accuracy                           0.08    464001
#    macro avg       0.53      0.50      0.07    464001
# weighted avg       0.92      0.08      0.01    464001
#
#
# Prediction Percentages :
#  1    0.999235
# 0    0.000765
# dtype: float64
# ------------------------------------------------------------
# Random_Guessing
#  Split: 0
# Random_Guessing 0th validation
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92    428277
#            1       0.08      0.08      0.08     35724
#
#     accuracy                           0.86    464001
#    macro avg       0.50      0.50      0.50    464001
# weighted avg       0.86      0.86      0.86    464001
#
#
# Prediction Percentages :
#  0    0.922571
# 1    0.077429
# dtype: float64
# ------------------------------------------------------------
# Guess_Everything_Natural
#  Split: 0
# Guess_Everything_Natural 0th validation
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    428277
#            1       0.00      0.00      0.00     35724
#
#     accuracy                           0.92    464001
#    macro avg       0.46      0.50      0.48    464001
# weighted avg       0.85      0.92      0.89    464001
#
#
# Prediction Percentages :
#  0    1.0
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression
#  Split: 0
# Logistic_Regression 0th validation
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    428277
#            1       0.48      0.12      0.19     35724
#
#     accuracy                           0.92    464001
#    macro avg       0.70      0.55      0.57    464001
# weighted avg       0.90      0.92      0.90    464001
#
#
# Prediction Percentages :
#  0    0.98114
# 1    0.01886
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Scaling+Weights
#  Split: 1
# Logistic_Regression_w_Scaling+Weights 1th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.70      0.32     35724
#
#     accuracy                           0.77    464001
#    macro avg       0.59      0.74      0.59    464001
# weighted avg       0.91      0.77      0.82    464001
#
#
# Prediction Percentages :
#  0    0.739899
# 1    0.260101
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Weights
#  Split: 1
# Logistic_Regression_w_Weights 1th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.70      0.32     35724
#
#     accuracy                           0.77    464001
#    macro avg       0.59      0.74      0.59    464001
# weighted avg       0.91      0.77      0.82    464001
#
#
# Prediction Percentages :
#  0    0.739684
# 1    0.260316
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier
#  Split: 1
# Random_Forest_Classifier 1th validation
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97    428277
#            1       0.68      0.26      0.38     35724
#
#     accuracy                           0.93    464001
#    macro avg       0.81      0.63      0.67    464001
# weighted avg       0.92      0.93      0.92    464001
#
#
# Prediction Percentages :
#  0    0.97042
# 1    0.02958
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier_w_Weights
#  Split: 1
# Random_Forest_Classifier_w_Weights 1th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90    428277
#            1       0.26      0.65      0.37     35724
#
#     accuracy                           0.83    464001
#    macro avg       0.61      0.75      0.64    464001
# weighted avg       0.91      0.83      0.86    464001
#
#
# Prediction Percentages :
#  0    0.8113
# 1    0.1887
# dtype: float64
# ------------------------------------------------------------
# Gaussian_Bayes
#  Split: 1
# Gaussian_Bayes 1th validation
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94    428277
#            1       0.32      0.37      0.34     35724
#
#     accuracy                           0.89    464001
#    macro avg       0.63      0.65      0.64    464001
# weighted avg       0.90      0.89      0.89    464001
#
#
# Prediction Percentages :
#  0    0.909448
# 1    0.090552
# dtype: float64
# ------------------------------------------------------------
# XGboost
#  Split: 1
# XGboost 1th validation
#                precision    recall  f1-score   support
#
#            0       0.98      0.00      0.00    428277
#            1       0.08      1.00      0.14     35724
#
#     accuracy                           0.08    464001
#    macro avg       0.53      0.50      0.07    464001
# weighted avg       0.91      0.08      0.01    464001
#
#
# Prediction Percentages :
#  1    0.999519
# 0    0.000481
# dtype: float64
# ------------------------------------------------------------
# Random_Guessing
#  Split: 1
# Random_Guessing 1th validation
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92    428277
#            1       0.08      0.08      0.08     35724
#
#     accuracy                           0.86    464001
#    macro avg       0.50      0.50      0.50    464001
# weighted avg       0.86      0.86      0.86    464001
#
#
# Prediction Percentages :
#  0    0.922778
# 1    0.077222
# dtype: float64
# ------------------------------------------------------------
# Guess_Everything_Natural
#  Split: 1
# Guess_Everything_Natural 1th validation
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    428277
#            1       0.00      0.00      0.00     35724
#
#     accuracy                           0.92    464001
#    macro avg       0.46      0.50      0.48    464001
# weighted avg       0.85      0.92      0.89    464001
#
#
# Prediction Percentages :
#  0    1.0
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression
#  Split: 1
# Logistic_Regression 1th validation
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    428277
#            1       0.47      0.12      0.19     35724
#
#     accuracy                           0.92    464001
#    macro avg       0.70      0.55      0.57    464001
# weighted avg       0.90      0.92      0.90    464001
#
#
# Prediction Percentages :
#  0    0.980974
# 1    0.019026
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Scaling+Weights
#  Split: 2
# Logistic_Regression_w_Scaling+Weights 2th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.738938
# 1    0.261062
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Weights
#  Split: 2
# Logistic_Regression_w_Weights 2th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.738377
# 1    0.261623
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier
#  Split: 2
# Random_Forest_Classifier 2th validation
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97    428277
#            1       0.69      0.26      0.38     35723
#
#     accuracy                           0.93    464000
#    macro avg       0.81      0.63      0.67    464000
# weighted avg       0.92      0.93      0.92    464000
#
#
# Prediction Percentages :
#  0    0.970735
# 1    0.029265
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier_w_Weights
#  Split: 2
# Random_Forest_Classifier_w_Weights 2th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90    428277
#            1       0.26      0.65      0.37     35723
#
#     accuracy                           0.83    464000
#    macro avg       0.61      0.75      0.64    464000
# weighted avg       0.91      0.83      0.86    464000
#
#
# Prediction Percentages :
#  0    0.806994
# 1    0.193006
# dtype: float64
# ------------------------------------------------------------
# Gaussian_Bayes
#  Split: 2
# Gaussian_Bayes 2th validation
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94    428277
#            1       0.32      0.37      0.34     35723
#
#     accuracy                           0.89    464000
#    macro avg       0.63      0.65      0.64    464000
# weighted avg       0.90      0.89      0.89    464000
#
#
# Prediction Percentages :
#  0    0.909875
# 1    0.090125
# dtype: float64
# ------------------------------------------------------------
# XGboost
#  Split: 2
# XGboost 2th validation
#                precision    recall  f1-score   support
#
#            0       0.98      0.00      0.00    428277
#            1       0.08      1.00      0.14     35723
#
#     accuracy                           0.08    464000
#    macro avg       0.53      0.50      0.07    464000
# weighted avg       0.91      0.08      0.01    464000
#
#
# Prediction Percentages :
#  1    0.999386
# 0    0.000614
# dtype: float64
# ------------------------------------------------------------
# Random_Guessing
#  Split: 2
# Random_Guessing 2th validation
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92    428277
#            1       0.08      0.08      0.08     35723
#
#     accuracy                           0.86    464000
#    macro avg       0.50      0.50      0.50    464000
# weighted avg       0.86      0.86      0.86    464000
#
#
# Prediction Percentages :
#  0    0.92383
# 1    0.07617
# dtype: float64
# ------------------------------------------------------------
# Guess_Everything_Natural
#  Split: 2
# Guess_Everything_Natural 2th validation
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    428277
#            1       0.00      0.00      0.00     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.46      0.50      0.48    464000
# weighted avg       0.85      0.92      0.89    464000
#
#
# Prediction Percentages :
#  0    1.0
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression
#  Split: 2
# Logistic_Regression 2th validation
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    428277
#            1       0.48      0.12      0.19     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.71      0.55      0.57    464000
# weighted avg       0.90      0.92      0.90    464000
#
#
# Prediction Percentages :
#  0    0.98131
# 1    0.01869
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Scaling+Weights
#  Split: 3
# Logistic_Regression_w_Scaling+Weights 3th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.33     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.740351
# 1    0.259649
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Weights
#  Split: 3
# Logistic_Regression_w_Weights 3th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.33     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.74045
# 1    0.25955
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier
#  Split: 3
# Random_Forest_Classifier 3th validation
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    428277
#            1       0.68      0.26      0.38     35723
#
#     accuracy                           0.93    464000
#    macro avg       0.81      0.63      0.67    464000
# weighted avg       0.92      0.93      0.92    464000
#
#
# Prediction Percentages :
#  0    0.970147
# 1    0.029853
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier_w_Weights
#  Split: 3
# Random_Forest_Classifier_w_Weights 3th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91    428277
#            1       0.27      0.65      0.38     35723
#
#     accuracy                           0.84    464000
#    macro avg       0.62      0.75      0.64    464000
# weighted avg       0.91      0.84      0.87    464000
#
#
# Prediction Percentages :
#  0    0.813155
# 1    0.186845
# dtype: float64
# ------------------------------------------------------------
# Gaussian_Bayes
#  Split: 3
# Gaussian_Bayes 3th validation
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94    428277
#            1       0.32      0.37      0.35     35723
#
#     accuracy                           0.89    464000
#    macro avg       0.63      0.65      0.64    464000
# weighted avg       0.90      0.89      0.89    464000
#
#
# Prediction Percentages :
#  0    0.909978
# 1    0.090022
# dtype: float64
# ------------------------------------------------------------
# XGboost
#  Split: 3
# XGboost 3th validation
#                precision    recall  f1-score   support
#
#            0       0.96      0.00      0.00    428277
#            1       0.08      1.00      0.14     35723
#
#     accuracy                           0.08    464000
#    macro avg       0.52      0.50      0.07    464000
# weighted avg       0.90      0.08      0.01    464000
#
#
# Prediction Percentages :
#  1    0.999291
# 0    0.000709
# dtype: float64
# ------------------------------------------------------------
# Random_Guessing
#  Split: 3
# Random_Guessing 3th validation
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92    428277
#            1       0.08      0.08      0.08     35723
#
#     accuracy                           0.86    464000
#    macro avg       0.50      0.50      0.50    464000
# weighted avg       0.86      0.86      0.86    464000
#
#
# Prediction Percentages :
#  0    0.922381
# 1    0.077619
# dtype: float64
# ------------------------------------------------------------
# Guess_Everything_Natural
#  Split: 3
# Guess_Everything_Natural 3th validation
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    428277
#            1       0.00      0.00      0.00     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.46      0.50      0.48    464000
# weighted avg       0.85      0.92      0.89    464000
#
#
# Prediction Percentages :
#  0    1.0
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression
#  Split: 3
# Logistic_Regression 3th validation
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    428277
#            1       0.47      0.11      0.18     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.70      0.55      0.57    464000
# weighted avg       0.90      0.92      0.90    464000
#
#
# Prediction Percentages :
#  0    0.981545
# 1    0.018455
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Scaling+Weights
#  Split: 4
# Logistic_Regression_w_Scaling+Weights 4th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.738364
# 1    0.261636
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression_w_Weights
#  Split: 4
# Logistic_Regression_w_Weights 4th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86    428277
#            1       0.21      0.71      0.32     35723
#
#     accuracy                           0.77    464000
#    macro avg       0.59      0.74      0.59    464000
# weighted avg       0.91      0.77      0.82    464000
#
#
# Prediction Percentages :
#  0    0.738116
# 1    0.261884
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier
#  Split: 4
# Random_Forest_Classifier 4th validation
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97    428277
#            1       0.68      0.27      0.38     35723
#
#     accuracy                           0.93    464000
#    macro avg       0.81      0.63      0.67    464000
# weighted avg       0.92      0.93      0.92    464000
#
#
# Prediction Percentages :
#  0    0.969828
# 1    0.030172
# dtype: float64
# ------------------------------------------------------------
# Random_Forest_Classifier_w_Weights
#  Split: 4
# Random_Forest_Classifier_w_Weights 4th validation
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90    428277
#            1       0.26      0.65      0.38     35723
#
#     accuracy                           0.83    464000
#    macro avg       0.62      0.75      0.64    464000
# weighted avg       0.91      0.83      0.86    464000
#
#
# Prediction Percentages :
#  0    0.810418
# 1    0.189582
# dtype: float64
# ------------------------------------------------------------
# Gaussian_Bayes
#  Split: 4
# Gaussian_Bayes 4th validation
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94    428277
#            1       0.32      0.38      0.35     35723
#
#     accuracy                           0.89    464000
#    macro avg       0.63      0.65      0.64    464000
# weighted avg       0.90      0.89      0.89    464000
#
#
# Prediction Percentages :
#  0    0.909776
# 1    0.090224
# dtype: float64
# ------------------------------------------------------------
# XGboost
#  Split: 4
# XGboost 4th validation
#                precision    recall  f1-score   support
#
#            0       0.98      0.00      0.00    428277
#            1       0.08      1.00      0.14     35723
#
#     accuracy                           0.08    464000
#    macro avg       0.53      0.50      0.07    464000
# weighted avg       0.91      0.08      0.01    464000
#
#
# Prediction Percentages :
#  1    0.999345
# 0    0.000655
# dtype: float64
# ------------------------------------------------------------
# Random_Guessing
#  Split: 4
# Random_Guessing 4th validation
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92    428277
#            1       0.07      0.07      0.07     35723
#
#     accuracy                           0.86    464000
#    macro avg       0.50      0.50      0.50    464000
# weighted avg       0.86      0.86      0.86    464000
#
#
# Prediction Percentages :
#  0    0.922358
# 1    0.077642
# dtype: float64
# ------------------------------------------------------------
# Guess_Everything_Natural
#  Split: 4
# Guess_Everything_Natural 4th validation
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    428277
#            1       0.00      0.00      0.00     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.46      0.50      0.48    464000
# weighted avg       0.85      0.92      0.89    464000
#
#
# Prediction Percentages :
#  0    1.0
# dtype: float64
# ------------------------------------------------------------
# Logistic_Regression
#  Split: 4
# Logistic_Regression 4th validation
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    428277
#            1       0.48      0.12      0.19     35723
#
#     accuracy                           0.92    464000
#    macro avg       0.70      0.55      0.57    464000
# weighted avg       0.90      0.92      0.90    464000
#
#
# Prediction Percentages :
#  0    0.98111
# 1    0.01889
# dtype: float64
# ------------------------------------------------------------

# %%
recalls = pd.DataFrame(rcls,
            index = list(models.keys()),
            columns = [f'recall_{i}' for i in range(n_splits)])
recalls['recall_mean'] = recalls.mean(axis=1)
f1_scores = pd.DataFrame(f1s,
            index = list(models.keys()),
            columns = [f'f1_macro_{i}' for i in range(n_splits)])
f1_scores['f1_mean'] = f1_scores.mean(axis=1)
display(pd.concat([recalls, f1_scores], axis=1))
# Out:
#                                        recall_0  recall_1  recall_2  recall_3  \
# Logistic_Regression_w_Scaling+Weights  0.706304  0.704596  0.709711  0.711082
# Logistic_Regression_w_Weights          0.706304  0.704736  0.710047  0.711055
# Random_Forest_Classifier               0.264304  0.262876  0.260728  0.262884
# Random_Forest_Classifier_w_Weights     0.649003  0.645280  0.653445  0.651373
# Gaussian_Bayes                         0.373222  0.371655  0.372617  0.374605
# XGboost                                0.999860  0.999860  0.999804  0.999664
# Random_Guessing                        0.076279  0.077315  0.076449  0.078213
# Guess_Everything_Natural               0.000000  0.000000  0.000000  0.000000
# Logistic_Regression                    0.116588  0.115888  0.116871  0.113764
#
#                                        recall_4  recall_mean  f1_macro_0  \
# Logistic_Regression_w_Scaling+Weights  0.711027     0.708544    0.592173
# Logistic_Regression_w_Weights          0.711278     0.708684    0.592173
# Random_Forest_Classifier               0.267811     0.263721    0.672305
# Random_Forest_Classifier_w_Weights     0.652325     0.650285    0.639499
# Gaussian_Bayes                         0.375416     0.373503    0.641470
# XGboost                                0.999804     0.999798    0.072345
# Random_Guessing                        0.074910     0.076633    0.499379
# Guess_Everything_Natural               0.000000     0.000000    0.479982
# Logistic_Regression                    0.117123     0.116047    0.573193
#
#                                        f1_macro_1  f1_macro_2  f1_macro_3  \
# Logistic_Regression_w_Scaling+Weights    0.592195    0.592806    0.594345
# Logistic_Regression_w_Weights            0.592057    0.592439    0.594420
# Random_Forest_Classifier                 0.672460    0.671463    0.671903
# Random_Forest_Classifier_w_Weights       0.639035    0.637376    0.642980
# Gaussian_Bayes                           0.640687    0.641728    0.642864
# XGboost                                  0.072018    0.072161    0.072248
# Random_Guessing                          0.500050    0.500151    0.500320
# Guess_Everything_Natural                 0.479982    0.479982    0.479982
# Logistic_Regression                      0.572397    0.573646    0.571309
#
#                                        f1_macro_4   f1_mean
# Logistic_Regression_w_Scaling+Weights    0.592696  0.592843
# Logistic_Regression_w_Weights            0.592562  0.592730
# Random_Forest_Classifier                 0.674992  0.672624
# Random_Forest_Classifier_w_Weights       0.640481  0.639874
# Gaussian_Bayes                           0.643004  0.641951
# XGboost                                  0.072208  0.072196
# Random_Guessing                          0.498525  0.499685
# Guess_Everything_Natural                 0.479982  0.479982
# Logistic_Regression                      0.573607  0.572830

# %% [markdown]
# Based on the output above, it seems that while considering both macro $f_1$ and recall, the model `RandomForestClassifer` with `class_weights = 'balanced'` seems like the model with the most potential.

# %% [markdown]
# ### 6.2) Hyperparameter Tuning for Best Candidate
#     Grid Search CV with RandomForestClassifer + class_weights

# %%
n_estimators = [2,3,5,7,10]
max_depth = [2,6,5,10,15]

param_grid = { 'n_estimators': n_estimators,
          #    'max_features': [ 'sqrt', 'log2'],
              'max_depth' : max_depth,
              'criterion' :['entropy']
             }

# %%
grid_cv=GridSearchCV(RandomForestClassifier(class_weight = 'balanced',random_state = 123),#put model here something lifinal_predictionsearRegression()
                     param_grid = param_grid,
                     scoring = 'f1_macro',
                     cv = StratifiedKFold(n_splits=5, random_state=101, shuffle=True),
                     verbose=4)


grid_cv.fit(df_train[features],df_train.unnatural)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=2;, score=0.614 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=2;, score=0.613 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=2;, score=0.614 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=2;, score=0.614 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=2;, score=0.613 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=3;, score=0.614 total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=3;, score=0.614 total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=3;, score=0.614 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=3;, score=0.614 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=3;, score=0.614 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=5;, score=0.639 total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=5;, score=0.638 total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=5;, score=0.639 total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=5;, score=0.639 total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=5;, score=0.639 total time=   1.5s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=7;, score=0.635 total time=   1.9s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=7;, score=0.635 total time=   1.8s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=7;, score=0.635 total time=   1.8s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=7;, score=0.637 total time=   1.9s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=7;, score=0.635 total time=   1.9s
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=0.639 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=0.638 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=0.639 total time=   2.4s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=0.639 total time=   2.5s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=10;, score=0.639 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=2;, score=0.627 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=2;, score=0.639 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=2;, score=0.632 total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=2;, score=0.628 total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=2;, score=0.622 total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=3;, score=0.638 total time=   1.6s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=3;, score=0.643 total time=   1.6s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=3;, score=0.637 total time=   1.6s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=3;, score=0.635 total time=   1.7s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=3;, score=0.637 total time=   1.6s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=5;, score=0.640 total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=5;, score=0.642 total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=5;, score=0.643 total time=   2.4s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=5;, score=0.638 total time=   2.6s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=5;, score=0.640 total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=7;, score=0.644 total time=   3.2s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=7;, score=0.643 total time=   3.4s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=7;, score=0.646 total time=   3.1s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=7;, score=0.643 total time=   3.4s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=7;, score=0.646 total time=   3.3s
# [CV 1/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=0.644 total time=   4.4s
# [CV 2/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=0.646 total time=   4.3s
# [CV 3/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=0.646 total time=   4.3s
# [CV 4/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=0.644 total time=   4.3s
# [CV 5/5] END criterion=entropy, max_depth=6, n_estimators=10;, score=0.647 total time=   4.4s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=2;, score=0.649 total time=   1.1s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=2;, score=0.649 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=2;, score=0.638 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=2;, score=0.638 total time=   1.1s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=2;, score=0.651 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=3;, score=0.649 total time=   1.4s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=3;, score=0.649 total time=   1.4s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=3;, score=0.639 total time=   1.4s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=3;, score=0.638 total time=   1.4s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=3;, score=0.650 total time=   1.4s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=5;, score=0.649 total time=   2.2s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=5;, score=0.650 total time=   2.3s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=5;, score=0.646 total time=   2.2s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=5;, score=0.643 total time=   2.2s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=5;, score=0.651 total time=   2.3s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=7;, score=0.636 total time=   2.9s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=7;, score=0.640 total time=   2.9s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=7;, score=0.632 total time=   2.9s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=7;, score=0.635 total time=   2.8s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=7;, score=0.641 total time=   3.0s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=10;, score=0.643 total time=   4.0s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=10;, score=0.644 total time=   3.9s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=10;, score=0.639 total time=   3.9s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=10;, score=0.643 total time=   4.0s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=10;, score=0.646 total time=   3.9s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=2;, score=0.635 total time=   1.4s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=2;, score=0.634 total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=2;, score=0.633 total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=2;, score=0.639 total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=2;, score=0.633 total time=   1.5s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=3;, score=0.635 total time=   2.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=3;, score=0.635 total time=   2.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=3;, score=0.639 total time=   2.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=3;, score=0.639 total time=   1.9s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=3;, score=0.636 total time=   2.2s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=5;, score=0.637 total time=   3.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=5;, score=0.636 total time=   3.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=5;, score=0.638 total time=   3.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=5;, score=0.638 total time=   3.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=5;, score=0.636 total time=   3.2s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=7;, score=0.635 total time=   4.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=7;, score=0.635 total time=   4.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=7;, score=0.635 total time=   4.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=7;, score=0.637 total time=   4.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=7;, score=0.638 total time=   4.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.636 total time=   5.8s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.637 total time=   5.9s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.635 total time=   5.9s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.638 total time=   5.8s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=10;, score=0.638 total time=   5.7s
# [CV 1/5] END criterion=entropy, max_depth=15, n_estimators=2;, score=0.634 total time=   1.7s
# [CV 2/5] END criterion=entropy, max_depth=15, n_estimators=2;, score=0.635 total time=   1.6s
# [CV 3/5] END criterion=entropy, max_depth=15, n_estimators=2;, score=0.633 total time=   1.6s
# [CV 4/5] END criterion=entropy, max_depth=15, n_estimators=2;, score=0.634 total time=   1.7s
# [CV 5/5] END criterion=entropy, max_depth=15, n_estimators=2;, score=0.634 total time=   1.7s
# [CV 1/5] END criterion=entropy, max_depth=15, n_estimators=3;, score=0.635 total time=   2.3s
# [CV 2/5] END criterion=entropy, max_depth=15, n_estimators=3;, score=0.634 total time=   2.3s
# [CV 3/5] END criterion=entropy, max_depth=15, n_estimators=3;, score=0.633 total time=   2.2s
# [CV 4/5] END criterion=entropy, max_depth=15, n_estimators=3;, score=0.634 total time=   2.3s
# [CV 5/5] END criterion=entropy, max_depth=15, n_estimators=3;, score=0.635 total time=   2.2s
# [CV 1/5] END criterion=entropy, max_depth=15, n_estimators=5;, score=0.635 total time=   3.6s
# [CV 2/5] END criterion=entropy, max_depth=15, n_estimators=5;, score=0.636 total time=   3.5s
# [CV 3/5] END criterion=entropy, max_depth=15, n_estimators=5;, score=0.634 total time=   3.5s
# [CV 4/5] END criterion=entropy, max_depth=15, n_estimators=5;, score=0.636 total time=   4.0s
# [CV 5/5] END criterion=entropy, max_depth=15, n_estimators=5;, score=0.636 total time=   3.5s
# [CV 1/5] END criterion=entropy, max_depth=15, n_estimators=7;, score=0.636 total time=   4.7s
# [CV 2/5] END criterion=entropy, max_depth=15, n_estimators=7;, score=0.636 total time=   5.0s
# [CV 3/5] END criterion=entropy, max_depth=15, n_estimators=7;, score=0.633 total time=   4.7s
# [CV 4/5] END criterion=entropy, max_depth=15, n_estimators=7;, score=0.636 total time=   5.5s
# [CV 5/5] END criterion=entropy, max_depth=15, n_estimators=7;, score=0.637 total time=   4.8s
# [CV 1/5] END criterion=entropy, max_depth=15, n_estimators=10;, score=0.636 total time=   6.6s
# [CV 2/5] END criterion=entropy, max_depth=15, n_estimators=10;, score=0.636 total time=   6.8s
# [CV 3/5] END criterion=entropy, max_depth=15, n_estimators=10;, score=0.634 total time=   6.7s
# [CV 4/5] END criterion=entropy, max_depth=15, n_estimators=10;, score=0.637 total time=   6.6s
# [CV 5/5] END criterion=entropy, max_depth=15, n_estimators=10;, score=0.636 total time=   6.5s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=101, shuffle=True),
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=123),
#              param_grid={'criterion': ['entropy'],
#                          'max_depth': [2, 6, 5, 10, 15],
#                          'n_estimators': [2, 3, 5, 7, 10]},
#              scoring='f1_macro', verbose=4)

# %%
grid_cv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 5}

# %%
results = pd.DataFrame(grid_cv.cv_results_)

fig = plt.figure(figsize=(10,5))
for md in max_depth:
    temp = results [ results['param_max_depth'] == md ]
    plt.plot(temp.param_n_estimators, temp.mean_test_score, label = f'max_depth = {md}')

plt.xlabel('n_estimators')
plt.ylabel('mean $f_1$-macro score')
plt.legend()
plt.show()

# %% [markdown]
# ## 7) Deploying the Final Model

# %% [markdown]
# Here, we will deploy the best model, whose hyperparameters were selected using `GridSearchCV`.  Below, we have plotted the resulting confusion matrix.

# %%
final_predictions = grid_cv.best_estimator_.predict(df_test[features])

cm = confusion_matrix(df_test.unnatural.values, final_predictions)

disp_cm = ConfusionMatrixDisplay(cm)

disp_cm.plot()

# %%
score_df = pd.DataFrame({'feature':features,
                            'importance_score': grid_cv.best_estimator_.feature_importances_})

score_df.sort_values('importance_score', ascending=False)
# Out:
#             feature  importance_score
# 0        detail_age          0.803768
# 4  marital_status_S          0.131128
# 6             sex_F          0.029270
# 2  marital_status_D          0.014232
# 1         education          0.013158
# 3  marital_status_M          0.008385
# 5  marital_status_U          0.000059

# %%
print(classification_report(df_test.unnatural.values, final_predictions))
print('f1 macro test score :', f1_score(df_test.unnatural.values, final_predictions, average = 'macro'))
print('recall test score :', recall_score(df_test.unnatural.values, final_predictions))

print('Prediction Percentages : \n', pd.Series(final_predictions).value_counts(normalize=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91    237933
#            1       0.27      0.63      0.38     19846
#
#     accuracy                           0.84    257779
#    macro avg       0.62      0.75      0.65    257779
# weighted avg       0.91      0.84      0.87    257779
#
# f1 macro test score : 0.6460830296921457
# recall test score : 0.6349390305351205
# Prediction Percentages :
#  0    0.821459
# 1    0.178541
# dtype: float64

# %% [markdown]
# # 8) Conclusion

# %% [markdown]
# 1. Our best model predicts unnatural death with a recall score of ~65%. That is, we are able to detect 65% of all unnatural deaths which can be considered as a significant improvement over random guessing (8% probability of correctly guessing an unnatural death based on proportions).
# 2. This prediction model does not sacrifice precision by classifying all deaths natural given the imbalanced nature of the data set. For instance we opt out of training XGBboost model since in this scenerio it predicts unnatural death 99% percent of the time. Our model predicts unnatural death only about 18% of the time.
# 3. Thanks to our final model choice, RandomForestClassifer, we are able to investigate feature importances. `marital_status` and `detail_age` seem to be the most important factors.
